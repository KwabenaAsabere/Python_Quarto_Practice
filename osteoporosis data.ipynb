# %%
import pandas as pd

# %%
osteo = pd.read_csv(r"C:\Users\KAsab\Downloads\osteoporosis_survey.csv")

# %%
osteo.head()
# Out:
#     Age  Gender                Race   BMI Smoking Heavy Drinking  \
# 0  69.0    Male  Non-Hispanic Black  26.7     Yes            Yes
# 1  54.0    Male  Non-Hispanic White  28.6     Yes            Yes
# 2  72.0    Male  Non-Hispanic White  28.9     Yes             No
# 3  73.0  Female  Non-Hispanic White  19.7      No             No
# 4  56.0    Male    Mexican American  41.7     Yes             No
#
#    Sleep Duration (Hours) Arthritis Liver Condition Parental Osteoporosis  \
# 0                     7.0       Yes              No                    No
# 1                     9.0        No              No                    No
# 2                     8.0        No              No                    No
# 3                     9.0       Yes              No                    No
# 4                     5.0       Yes              No                    No
#
#   Osteoporosis
# 0           No
# 1           No
# 2          Yes
# 3           No
# 4           No
